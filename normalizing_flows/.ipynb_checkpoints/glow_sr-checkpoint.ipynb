# %%
# %load_ext autoreload

# %autoreload 2
# %env OMP_NUM_THREADS=8
# Out:
# env: OMP_NUM_THREADS=8

# %%
import sys, os, glob
sys.path += ['.']

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
from flows.cglow import CGlowFlowSR
from flows.invert import Invert
from flows.cglow.cond_affine_coupling import cond_coupling_nn_glow
from flows.cglow.cond_gaussianize import cond_gaussianize
from flows.glow.affine_coupling import coupling_nn_glow
from flows.cglow.affine_injector import injector_nn_glow
from models.flvm import FlowLVM

import matplotlib.pyplot as plt
import h5py
from matplotlib.colors import LogNorm, SymLogNorm

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(3)

# %%
dset_dir = '/home/cluster/hlasco/bulk1/GAN_dataset/'
fList_t  = glob.glob(dset_dir+'/train/*/processed_data/snapshot.h5')
fList_v  = glob.glob(dset_dir+'/validation/*/processed_data/snapshot.h5')
nFiles_t = len(fList_t)

# %%
dset_dir = '/home/cluster/hlasco/bulk1/GAN_dataset/'
fList_t  = glob.glob(dset_dir+'/train/*/processed_data/snapshot.h5')
fList_v  = glob.glob(dset_dir+'/validation/*/processed_data/snapshot.h5')
nFiles_t = len(fList_t)

ps_h = 32
ps_l = 32//4

# read .h5 file
def readH5(f):
    f = f.numpy()
    idx = np.random.randint(0,8)
    idy = np.random.randint(0,8)
    idz = np.random.randint(0,8)
    with h5py.File(f, 'r') as fi:
        u_hr = np.array(fi['HR/ux'][idx*ps_h:(idx+1)*ps_h,idy*ps_h:(idy+1)*ps_h,idz*ps_h:(idz+1)*ps_h], dtype=np.float32).reshape(ps_h,ps_h,ps_h,1)
        u_lr = np.array(fi['LR/ux'][idx*ps_l:(idx+1)*ps_l,idy*ps_l:(idy+1)*ps_l,idz*ps_l:(idz+1)*ps_l], dtype=np.float32).reshape(ps_l,ps_l,ps_l,1)
        v_hr = np.array(fi['HR/uy'][idx*ps_h:(idx+1)*ps_h,idy*ps_h:(idy+1)*ps_h,idz*ps_h:(idz+1)*ps_h], dtype=np.float32).reshape(ps_h,ps_h,ps_h,1)
        v_lr = np.array(fi['LR/uy'][idx*ps_l:(idx+1)*ps_l,idy*ps_l:(idy+1)*ps_l,idz*ps_l:(idz+1)*ps_l], dtype=np.float32).reshape(ps_l,ps_l,ps_l,1)
        w_hr = np.array(fi['HR/uz'][idx*ps_h:(idx+1)*ps_h,idy*ps_h:(idy+1)*ps_h,idz*ps_h:(idz+1)*ps_h], dtype=np.float32).reshape(ps_h,ps_h,ps_h,1)
        w_lr = np.array(fi['LR/uz'][idx*ps_l:(idx+1)*ps_l,idy*ps_l:(idy+1)*ps_l,idz*ps_l:(idz+1)*ps_l], dtype=np.float32).reshape(ps_l,ps_l,ps_l,1)
        r_hr = np.array(fi['HR/rho'][idx*ps_h:(idx+1)*ps_h,idy*ps_h:(idy+1)*ps_h,idz*ps_h:(idz+1)*ps_h], dtype=np.float32).reshape(ps_h,ps_h,ps_h,1)
        r_lr = np.array(fi['LR/rho'][idx*ps_l:(idx+1)*ps_l,idy*ps_l:(idy+1)*ps_l,idz*ps_l:(idz+1)*ps_l], dtype=np.float32).reshape(ps_l,ps_l,ps_l,1)
        
        m_vel = np.mean([u_hr, v_hr, w_hr])
        s_vel = np.std([u_hr, v_hr, w_hr])
        
        r_hr = np.log10(r_hr)
        r_lr = np.log10(r_lr)
        
        m_r = np.mean(r_hr)
        s_r = np.std(r_hr)

        u_hr = (u_hr - np.mean(u_lr))/np.std(u_lr)                              u_lr = (u_lr - np.mean(u_lr))/np.std(u_lr)
        v_hr = (v_hr - np.mean(v_lr))/np.std(v_lr)                                   v_lr = (v_lr - np.mean(v_lr))/np.std(v_lr)
        w_hr = (w_hr - np.mean(w_lr))/np.std(w_lr)
        w_lr = (w_lr - np.mean(w_lr))/np.std(w_lr)                                   r_hr = (r_hr - m_r)/s_r
        r_lr = (r_lr - m_r)/s_r
        
        return np.concatenate((u_lr, v_lr, w_lr, r_lr), axis=-1), np.concatenate((u_hr, v_hr, w_hr, r_hr), axis=-1)


def readH5_wrapper(filename):
    # Assuming your data and labels are float32
    # Your input is parse_function, who arg is filename, and you get X and y as output
    # whose datatypes are indicated by the tuple argument
    lr, hr = tf.py_function(readH5, [filename], (tf.float32, tf.float32))
    return hr, lr

batch_size = 1
# Create dataset of filenames.
X_train_ds = tf.data.Dataset.from_tensor_slices(fList_t)
X_train_ds = X_train_ds.map(readH5_wrapper)
X_train_ds = X_train_ds.batch(batch_size).repeat()
#X_train_ds = X_train_ds.batch(1).repeat()
# Out:
#   File "<ipython-input-6-0920b5d8e57d>", line 34
#     u_hr = (u_hr - np.mean(u_lr))/np.std(u_lr)                              u_lr = (u_lr - np.mean(u_lr))/np.std(u_lr)
#                                                                             ^
# SyntaxError: invalid syntax

# %%
iterator = iter(X_train_ds)
images, labels = iterator.get_next()
print(images.shape, labels.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6ea75b0905fd> in <module>
# ----> 1 iterator = iter(X_train_ds)
#       2 images, labels = iterator.get_next()
#       3 print(images.shape, labels.shape)
#
# NameError: name 'X_train_ds' is not defined

# %%
def spectrum2d(image):
    n, _ = image.shape
    fourier_image = np.fft.fftn(image) / n**2
    fourier_amplitudes = np.abs(fourier_image)**2
    
    kmin = 1.0
    kmax = kmin + n//2+1
    
    kbins = np.arange(kmin, kmax, kmin)
    N = len(kbins)

    kfreq = np.fft.fftfreq(n) * n
    
    kfreq2D = np.meshgrid(kfreq, kfreq)
    k = np.sqrt(kfreq2D[0]**2 + kfreq2D[1]**2)
    
    whichbin = np.digitize(k.flat, kbins)
    ncount = np.bincount(whichbin)
    
    E_k = np.zeros(len(ncount)-1)
    
    for n in range(1,len(ncount)):
        E_k[n-1] = np.sum(fourier_amplitudes.flat[whichbin==n])

    k = 0.5*(kbins[0:N-1] + kbins[1:N])
    E_k = E_k[1:N]
    
    return k[:-1], E_k[:-1]

# %%
def p_spectrum3d(rho):
    nx, ny, nz = rho.shape
    #box_radius = nx//2+1
    #rho = rho/np.mean(rho)
    Kk = np.zeros((nx,ny,nz))#( (nx//2+1, ny//2+1, nz//2+1))
    Pk = fft_comp(rho)

    kx = np.fft.fftfreq(nx)*nx
    ky = np.fft.fftfreq(ny)*ny
    kz = np.fft.fftfreq(nz)*nz

    # physical limits to the wavenumbers
    kmin = 1.0
    kmax = nx//2+1

    kbins = np.arange(kmin, kmax, kmin)
    N = len(kbins)

    # bin the Fourier KE into radial kbins
    kx3d, ky3d, kz3d = np.meshgrid(kx, ky, kz, indexing="ij")
    k = np.sqrt(kx3d**2 + ky3d**2 + kz3d**2)

    whichbin = np.digitize(k.flat, kbins)
    ncount = np.bincount(whichbin)

    P_k = np.zeros(len(ncount)-1)

    for n in range(1,len(ncount)):
        P_k[n-1] = np.mean(Pk.flat[whichbin==n])

    k = 0.5*(kbins[0:N-1] + kbins[1:N])
    P_k = P_k[1:N]

    return k[:-1], P_k[:-1]#/np.sum(P_k)

def e_spectrum3d(vel):
    u = vel[:,:,:,0]
    v = vel[:,:,:,1]
    w = vel[:,:,:,2]
    nx, ny, nz = u.shape
    #box_radius = nx//2+1

    Kk = np.zeros((nx,ny,nz))#( (nx//2+1, ny//2+1, nz//2+1))
    for comp in [u, v, w]:

        Kk += 0.5*fft_comp(comp)

    kx = np.fft.fftfreq(nx)*nx
    ky = np.fft.fftfreq(ny)*ny
    kz = np.fft.fftfreq(nz)*nz

    # physical limits to the wavenumbers
    kmin = 1.0
    kmax = nx//2+1

    kbins = np.arange(kmin, kmax, kmin)
    N = len(kbins)

    # bin the Fourier KE into radial kbins
    kx3d, ky3d, kz3d = np.meshgrid(kx, ky, kz, indexing="ij")
    k = np.sqrt(kx3d**2 + ky3d**2 + kz3d**2)

    whichbin = np.digitize(k.flat, kbins)
    ncount = np.bincount(whichbin)

    E_k = np.zeros(len(ncount)-1)

    for n in range(1,len(ncount)):
        E_k[n-1] = np.sum(Kk.flat[whichbin==n])

    k = 0.5*(kbins[0:N-1] + kbins[1:N])
    E_k = E_k[1:N]

    return k[:-1], E_k[:-1]#/np.sum(E_k)


def fft_comp(u):
    nx, ny, nz = u.shape
    ret = np.fft.fftn(u)#[0:nx//2+1,0:ny//2+1,0:nz//2+1]
    ret = ret/(nx*ny*nz)

    return np.abs(ret**2)

# %%
def readCube_v(f, s=64):
    print(f)
    with h5py.File(f, 'r') as fi:
        u_hr = np.array(fi['HR/ux'][:s, :s, :s], dtype=np.float32).reshape(1,s,s,s,1)
        u_lr = np.array(fi['LR/ux'][:s//4, :s//4, :s//4], dtype=np.float32).reshape(1,s//4,s//4,s//4,1)
        
        v_hr = np.array(fi['HR/uy'][:s, :s, :s], dtype=np.float32).reshape(1,s,s,s,1)
        v_lr = np.array(fi['LR/uy'][:s//4, :s//4, :s//4], dtype=np.float32).reshape(1,s//4,s//4,s//4,1)
        
        w_hr = np.array(fi['HR/uz'][:s, :s, :s], dtype=np.float32).reshape(1,s,s,s,1)
        w_lr = np.array(fi['LR/uz'][:s//4, :s//4, :s//4], dtype=np.float32).reshape(1,s//4,s//4,s//4,1)

        u_hr = (u_hr - np.mean(u_lr))/np.std(u_lr)
        u_lr = (u_lr - np.mean(u_lr))/np.std(u_lr)

        v_hr = (v_hr - np.mean(v_lr))/np.std(v_lr)
        v_lr = (v_lr - np.mean(v_lr))/np.std(v_lr)

        w_hr = (w_hr - np.mean(w_lr))/np.std(w_lr)
        w_lr = (w_lr - np.mean(w_lr))/np.std(w_lr)

        return np.concatenate((u_lr, v_lr, w_lr), axis=-1), np.concatenate((u_hr, v_hr, w_hr), axis=-1)

# %%
def readCube(f, s=64):
    print(f)
    with h5py.File(f, 'r') as fi:
        u_hr = np.array(fi['HR/ux'][:s, :s, :s], dtype=np.float32).reshape(1,s,s,s,1)
        u_lr = np.array(fi['LR/ux'][:s//4, :s//4, :s//4], dtype=np.float32).reshape(1,s//4,s//4,s//4,1)
        
        v_hr = np.array(fi['HR/uy'][:s, :s, :s], dtype=np.float32).reshape(1,s,s,s,1)
        v_lr = np.array(fi['LR/uy'][:s//4, :s//4, :s//4], dtype=np.float32).reshape(1,s//4,s//4,s//4,1)
        
        w_hr = np.array(fi['HR/uz'][:s, :s, :s], dtype=np.float32).reshape(1,s,s,s,1)
        w_lr = np.array(fi['LR/uz'][:s//4, :s//4, :s//4], dtype=np.float32).reshape(1,s//4,s//4,s//4,1)
        
        r_hr = np.array(fi['HR/rho'][:s, :s, :s], dtype=np.float32).reshape(1,s,s,s,1)
        r_lr = np.array(fi['LR/rho'][:s//4, :s//4, :s//4], dtype=np.float32).reshape(1,s//4,s//4,s//4,1)
        
        r_hr = np.log10(r_hr)
        r_lr = np.log10(r_lr)

        m_r = np.mean(r_lr)
        s_r = np.std(r_lr)

        u_hr = (u_hr - np.mean(u_lr))/np.std(u_lr)
        u_lr = (u_lr - np.mean(u_lr))/np.std(u_lr)

        v_hr = (v_hr - np.mean(v_lr))/np.std(v_lr)
        v_lr = (v_lr - np.mean(v_lr))/np.std(v_lr)

        w_hr = (w_hr - np.mean(w_lr))/np.std(w_lr)
        w_lr = (w_lr - np.mean(w_lr))/np.std(w_lr)

        r_hr = (r_hr - m_r)/s_r
        r_lr = (r_lr - m_r)/s_r
        return np.concatenate((u_lr, v_lr, w_lr, r_lr), axis=-1), np.concatenate((u_hr, v_hr, w_hr, r_hr), axis=-1)

# %%
kwargs_nn={'dim':3, 'min_filters':8, 'max_filters':128, 'num_blocks':0}

affine_coupling = coupling_nn_glow(**kwargs_nn)
cond_coupling = cond_coupling_nn_glow(**kwargs_nn)
injector = injector_nn_glow(**kwargs_nn)
parametrizer = cond_gaussianize(**kwargs_nn)
shape_cond = tf.TensorShape((None,None,None,None,4))
shape_inpt = tf.TensorShape((None,None,None,None,4))
glow = Invert(CGlowFlowSR(
                   upfactor=2,
                   num_layers=3,
                   depth=16,
                   cond_shape=shape_cond,
                   cond_filters=32,
                   cond_resblocks=8,
                   cond_blocks=4,
                   cond_coupling_nn_ctor=cond_coupling,
                   injector_nn_ctor=injector,
                   parameterize_ctor=parametrizer))

learning_rate = 1.0e-4
prior = tfp.distributions.Normal(loc=0.0, scale=1.0)
opt_flow = tf.keras.optimizers.Adam(learning_rate=learning_rate)
opt_cond = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model = FlowLVM(glow, prior, 
                input_shape=shape_inpt, 
                optimizer_flow=opt_flow,
                optimizer_cond=opt_cond)
print(model.param_count())
# Out:
# 889248
# tf.Tensor(26487520, shape=(), dtype=int32)

# %%
16/8
# Out:
# 2.0

# %%
model._init_checkpoint()
model.load(
    '/home/cluster/hlasco/scratch/srflow_3d/flow_3_16_16_32_cond_64_12_4/model', 
           save_num=22)

# %%
model._init_checkpoint()
model.load(
    '/home/cluster/hlasco/scratch/srflow_3d/flow_3_32_8_8_cond_64_12_4/model', 
           save_num=2)

# %%
model._init_checkpoint()
model.load(
    '/home/cluster/hlasco/scratch/srflow_3d/3_16_8_128_0/model', 
           save_num=39)

# %%
#from mpl_toolkits.mplot3d import Axes3D
#x = np.linspace(0.,1.0, 500)
#y = np.linspace(0.,1.0, 500)
#xx, yy = np.meshgrid(x,y)
##plt.plot(x, np.log(-x + 1e-7))
##plt.plot(x,np.log(1-x + 1e-7)+np.log(x + 1e-7))
#z = -.5*(yy*np.log(xx + 1e-2) + (1-yy)*np.log(1-x + 1e-2))
#ax = plt.subplot(1,1,1,projection='3d')
#ax.plot_surface(xx, yy, z)
#plt.show()
#
#ax = plt.subplot(1,1,1,projection='3d')
#z = np.log(yy+1e-2) + np.log(1-xx + 1e-2)
#ax.plot_surface(xx, yy, .1*.5*z, rcount=100, ccount=100)

# %%
model.test(shape=[1,32,32,32,4], y_shape=[1,8,8,8,4])
# Out:
# Testing individual layers:
# Testing cglow_flow_layer0_squeeze
# 	 passed
# 	 Num params: 0
# Testing cglow_flow_layer0_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -9.858143e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.2361439e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step0_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.2582074e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step0_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.5773887e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step0_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step0_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step1_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.1946562e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step1_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.5805837e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step1_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step1_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step2_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 6.298448e-12
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step2_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -6.6656397e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step2_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step2_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step3_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -4.395466e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step3_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.1104822e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step3_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step3_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step4_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -9.064691e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step4_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.4230775e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step4_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step4_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step5_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 5.5002614e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step5_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.8600064e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step5_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step5_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step6_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 7.7825396e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step6_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 3.177944e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step6_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step6_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step7_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 3.304621e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step7_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 8.7369934e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step7_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step7_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step8_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -2.365905e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step8_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 2.3809061e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step8_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step8_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step9_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 7.65688e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step9_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.9400135e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step9_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step9_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step10_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.1477019e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step10_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.1455802e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step10_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step10_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step11_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 6.505575e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step11_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -5.977161e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step11_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step11_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step12_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.0201049e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step12_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.5244341e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step12_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step12_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step13_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.058909e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step13_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -8.1647056e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step13_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step13_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step14_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 5.368309e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step14_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.1562226e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step14_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step14_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step15_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 6.785562e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step15_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 4.8345394e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step15_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(221408, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step15_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(304432, shape=(), dtype=int32)
# Testing cglow_flow_layer0_split
# 	 passed
# 	 Num params: 608544
# Testing cglow_flow_layer1_squeeze
# 	 passed
# 	 Num params: 0
# Testing cglow_flow_layer1_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -9.0012275e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 3.592098e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step0_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.004163e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step0_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.9585943e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step0_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step0_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step1_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 6.919607e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step1_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 7.40694e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step1_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step1_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step2_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -6.38159e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step2_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.7671022e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step2_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step2_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step3_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -7.089446e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step3_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.0170686e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step3_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step3_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step4_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -5.1101845e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step4_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.4514179e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step4_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step4_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step5_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 7.7325e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step5_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.4533159e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step5_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step5_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step6_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 8.7539104e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step6_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 3.4018115e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step6_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step6_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step7_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 3.5730952e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step7_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -2.008026e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step7_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step7_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step8_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -8.456873e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step8_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 3.7218307e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step8_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step8_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step9_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -5.203481e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step9_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 2.2690116e-09
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step9_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step9_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step10_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.2045676e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step10_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.1338168e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step10_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step10_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step11_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -4.913888e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step11_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -5.7470395e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step11_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step11_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step12_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.2240238e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step12_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -4.0427963e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step12_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step12_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step13_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 6.181011e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step13_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 4.122844e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step13_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step13_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step14_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -4.987724e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step14_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.3984403e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step14_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step14_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step15_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 5.4875016e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(256, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step15_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -2.4865074e-08
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(49408, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step15_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(138656, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step15_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(117760, shape=(), dtype=int32)
# Testing cglow_flow_layer1_split
# 	 passed
# 	 Num params: 235200
# Testing cglow_flow_layer2_squeeze
# 	 passed
# 	 Num params: 0
# Testing cglow_flow_layer2_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 4.9363336e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.4975228e-07
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(787456, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step0_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -5.526181e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step0_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step0_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step1_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -4.5582205e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step1_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step1_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step2_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 3.228398e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step2_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step2_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step3_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.818057e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step3_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step3_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step4_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.4356993e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step4_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step4_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step5_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 2.6905478e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step5_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step5_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step6_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -5.545922e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step6_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step6_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step7_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 2.9707908e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step7_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step7_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step8_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.7856684e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step8_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step8_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step9_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.4591928e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step9_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step9_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step10_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.4051872e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step10_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step10_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step11_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 3.00987e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step11_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step11_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step12_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 2.5509805e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step12_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step12_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step13_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.4301146e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step13_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step13_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step14_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 3.3757086e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step14_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step14_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step15_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -6.1436406e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(1024, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step15_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(119048, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step15_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(91072, shape=(), dtype=int32)
# Testing cglow_flow_layer2_split
# 	 passed
# 	 Num params: 181104
# Testing cglow_flow_layer3_squeeze
# 	 passed
# 	 Num params: 0
# Testing cglow_flow_layer3_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -9.96937e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_inv_conv
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -4.413189e-06
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(12587008, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step0_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.1414997e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step0_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step0_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step1_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -7.018475e-11
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step1_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step1_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step2_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.1755308e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step2_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step2_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step3_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.1642737e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step3_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step3_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step4_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.621685e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step4_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step4_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step5_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -7.0881967e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step5_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step5_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step6_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 6.720664e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step6_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step6_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step7_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 4.3024606e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step7_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step7_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step8_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.6494274e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step8_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step8_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step9_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 5.4320504e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step9_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step9_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step10_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -6.410872e-12
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step10_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step10_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step11_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -1.7297719e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step11_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step11_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step12_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 5.7424754e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step12_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step12_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step13_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 6.679094e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step13_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step13_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step14_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -3.5523984e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step14_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step14_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step15_act_norm
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.272209e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(4096, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step15_affine_injector
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(118466, shape=(), dtype=int32)
# Testing cglow_flow_layer3_step15_cond_affine_coupling
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 0.0
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: tf.Tensor(87775, shape=(), dtype=int32)
# Testing cond_gaussianize
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): -2.9438518e-10
# 		ildj+fldj: 0.0
# 	 passed
# 	 Num params: 339386
# Testing full model:
# 	Error on forward inverse pass:
# 		x-F^{-1}oF(x): 1.8083875e-06
# 		ildj+fldj: -0.0009765625
# 	passed

# %%
def plotz_v(model, s, n, tau, c=2):
    #iterator = iter(X_train_ds)
    lr, hr = readCube_v(fList_t[0], s=s)
    sr = model.sample(n=1, shape=hr.shape, tau=tau, y_cond=lr)
    sr_spectrum = model.sample(n=n, shape=hr.shape, tau=tau, y_cond=lr)
    sr_det = model.sample(n=1, shape=hr.shape, tau=0.0, y_cond=lr)
    print('Sampling Done')
    z = model.encode(hr, y_cond=lr)

    
    plt.figure(figsize=(4*6,4))
    plt.subplot(1,3,1)
    plt.imshow(z[0,0,:,:,c], vmin=-4, vmax=4, cmap='Greys')
    plt.title(r'$z=f^{-1}(HR;LR)$')
    plt.yticks([])
    plt.xticks([])

    plt.subplot(1,3,2)
    bins = np.linspace(-5,5,100)
    plt.title(r'$p(z)$')
    h = plt.hist(z.numpy()[:,:,:,:,:].reshape(-1), bins=bins, density=True)
    #plt.yscale('log')
    plt.plot(bins, prior.prob(bins), 'k')
    
    ax1 = plt.subplot(1,3,3)
    k_hr, E_hr = e_spectrum3d(hr[0,:,:,:,:])
    k_sr_d, E_sr_d = e_spectrum3d(sr_det[0,:,:,:,:])
    k_sr, E_sr = e_spectrum3d(sr[0,:,:,:,:])
    fac = 0
    for i in range(n-1):
        u = sr_spectrum[i,:,:,:,:] 
        k_sr, E_sr = e_spectrum3d(u)
        ax1.loglog(k_sr, E_sr, color='g', alpha=2.0/n, linewidth=3)
    ax1.loglog(k_sr, E_sr, color='g', label=r'sampled $\tau=1$')
    ax1.loglog(k_hr, E_hr, 'k--', label=r'ground truth')
    ax1.loglog(k_sr_d, E_sr_d, label=r'sampled $\tau=0$')

    plt.legend()
    vmax = np.max((hr[0,:,:,0,c]))
    vmin = np.min((hr[0,:,:,0,c]))

    cmap="RdBu_r"

    plt.figure(figsize=(4*6,6))
    ax = plt.subplot(1,4,1)
    plt.imshow(hr[0,:,:,0,c], cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'ground truth')
    plt.subplot(1,4,2)
    plt.imshow(sr[0,:,:,0,c], cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'sampled $\tau=1$')
    plt.subplot(1,4,3)
    plt.imshow(sr_det[0,:,:,0,c], cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'sampled $\tau=0$')
    plt.subplot(1,4,4)
    plt.imshow(sr[0,:,:,0,c]-sr_det[0,:,:,0,c], cmap=cmap)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'$SR_{\tau=1} - SR_{\tau=0}$')
    plt.show()

# %%
def plotz(model, s, n, tau, c=2):
    #iterator = iter(X_train_ds)
    lr, hr = readCube(fList_t[0], s=s)
    N = 16
    hr = np.float32(hr + np.random.uniform(-.5/N, .5/N, hr.shape))
    #lr = np.float32(lr + np.random.uniform(-.5/N, .5/N, lr.shape))
    #lr[:,:,:,:,:3]*=0
    sr = model.sample(n=1, shape=hr.shape, tau=tau, y_cond=lr)
    sr_spectrum = model.sample(n=n, shape=hr.shape, tau=tau, y_cond=lr)
    sr_det = model.sample(n=1, shape=hr.shape, tau=0.0, y_cond=lr)
    #hr[:,:,:,:,3] = hr[:,:,:,:,3] / np.mean(hr[:,:,:,:,3]**2)**.5
    #sr[:,:,:,:,3] = sr[:,:,:,:,3] / np.mean(sr[:,:,:,:,3]**2)**.5
    print('Sampling Done')
    z = model.encode(hr, y_cond=lr)

    
    plt.figure(figsize=(4*6,4))
    ax1 = plt.subplot(1,4,1)
    ax2 = plt.subplot(1,4,2)
    ax3 = plt.subplot(1,4,3)
    ax4 = plt.subplot(1,4,4)
    k_hr, E_hr = e_spectrum3d(hr[0,:,:,:,:])
    k_hr, P_hr = p_spectrum3d(hr[0,:,:,:,3])
    k_sr_d, E_sr_d = e_spectrum3d(sr_det[0,:,:,:,:])
    k_sr_d, P_sr_d = p_spectrum3d(sr_det[0,:,:,:,3])
    k_sr, E_sr = e_spectrum3d(sr[0,:,:,:,:])
    k_sr, P_sr = p_spectrum3d(sr[0,:,:,:,3])
    fac = 0
    for i in range(n-1):
        u = sr_spectrum[i,:,:,:,:] 
        rho = sr_spectrum[i,:,:,:,3] 
        k_sr, E_sr = e_spectrum3d(u)
        k_sr, P_sr = p_spectrum3d(rho)
        ax1.loglog(k_sr, E_sr, color='g', alpha=2.0/n, linewidth=3)
        ax2.loglog(k_sr, P_sr, color='g', alpha=2.0/n, linewidth=3)
        ax3.semilogx(k_sr, 100*(E_sr-E_hr)/(E_hr), color='g', alpha=2.0/n, linewidth=3)
        ax4.semilogx(k_sr, 100*(P_sr-P_hr)/(P_hr), color='g', alpha=2.0/n, linewidth=3)

    ax3.semilogx(k_sr, 100*(E_sr-E_hr)/(E_hr), color='g', label=r'sampled $\tau=1$')
    ax3.semilogx(k_hr, 100*(E_hr-E_hr)/(E_hr), 'k--', label=r'ground truth')
    ax3.semilogx(k_sr_d, 100*(E_sr_d-E_hr)/(E_hr), label=r'sampled $\tau=0$')
    ax3.fill_between(k_hr, np.zeros_like(k_hr) + 10, np.zeros_like(k_hr) - 10, color='k', alpha=.3)
    ax3.set_ylim(-50,50)
    ax1.loglog(k_sr, E_sr, color='g', label=r'sampled $\tau=1$')
    ax1.loglog(k_hr, E_hr, 'k--', label=r'ground truth')
    ax1.loglog(k_sr_d, E_sr_d, label=r'sampled $\tau=0$')
    
    ax4.semilogx(k_sr, 100*(P_sr-P_hr)/(P_hr), color='g', label=r'sampled')
    ax4.semilogx(k_hr, 100*(P_hr-P_hr)/(P_hr), 'k--', label=r'ground truth')
    ax4.semilogx(k_sr_d, 100*(P_sr_d-P_hr)/(P_hr), label=r'sampled $\tau=0$')
    ax4.fill_between(k_hr, np.zeros_like(k_hr) + 10, np.zeros_like(k_hr) - 10, color='k', alpha=.3)
    ax4.set_ylim(-50,50)
    ax2.loglog(k_sr, P_sr, color='g', label=r'sampled')
    ax2.loglog(k_hr, P_hr, 'k--', label=r'ground truth')
    ax2.loglog(k_sr_d, P_sr_d, label=r'sampled $\tau=0$')

    plt.legend()
    vmax = np.max((hr[0,:,:,0,c]))
    vmin = np.min((hr[0,:,:,0,c]))

    cmap="RdBu_r"

    plt.figure(figsize=(4*6,6))
    ax = plt.subplot(1,4,1)
    plt.imshow(hr[0,:,:,0,c], cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'ground truth')
    plt.subplot(1,4,2)
    plt.imshow(sr[0,:,:,0,c], cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'sampled $\tau=1$')
    plt.subplot(1,4,3)
    plt.imshow(sr_det[0,:,:,0,c], cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'sampled $\tau=0$')
    plt.subplot(1,4,4)
    plt.imshow(lr[0,:,:,0,c], cmap=cmap, vmin=vmin, vmax=vmax)
    #plt.imshow(sr[0,:,:,32,c]-sr_det[0,:,:,32,c], cmap=cmap)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'low res')
    #plt.title(r'$SR_{\tau=1} - SR_{\tau=0}$')
    plt.show()
    
    vmax = np.max((hr[0,:,:,0,3]))
    vmin = np.min((hr[0,:,:,0,3]))
    cmap="inferno"
    plt.figure(figsize=(4*6,6))
    ax = plt.subplot(1,4,1)
    plt.imshow(hr[0,:,:,0,3], cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'ground truth')
    plt.subplot(1,4,2)
    plt.imshow(sr[0,:,:,0,3], cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'sampled $\tau=1$')
    plt.subplot(1,4,3)
    plt.imshow(sr_det[0,:,:,0,3], cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks([])
    plt.xticks([])
    plt.title(r'sampled $\tau=0$')
    plt.subplot(1,4,4)
    plt.imshow(lr[0,:,:,0,3], cmap=cmap, vmin=vmin, vmax=vmax)
    #plt.imshow(sr[0,:,:,32,3]-sr_det[0,:,:,32,3], cmap=cmap)
    plt.yticks([])
    plt.xticks([])
    #plt.title(r'$SR_{\tau=1} - SR_{\tau=0}$')
    plt.title(r'low res')
    plt.show()

# %%
#s=64
#lr, hr = readCube(fList_v[0], s=s)
#n = 20
#hr = hr + np.random.uniform(-.5/n, .5/n, hr.shape)
#print(.5/n)
#k_hr, E_hr = e_spectrum3d(hr[0,:,:,:,:3])
#k_hr, P_hr = p_spectrum3d(hr[0,:,:,:,3])
#
#k_hr, E_hr1 = e_spectrum3d(hr1[0,:,:,:,:3])
#k_hr, P_hr1 = p_spectrum3d(hr1[0,:,:,:,3])
#
#plt.loglog(k_hr, E_hr, 'k--')
#plt.loglog(k_hr, P_hr, 'k')
#
#plt.loglog(k_hr, E_hr1, 'b--')
#plt.loglog(k_hr, P_hr1, 'b')
#plt.show()
#plt.imshow(hr1[0,:,:,0,3])
#

# %%
plotz(model, s=64, n=0, tau=1.0, c=0)
# Out:
# /home/cluster/hlasco/bulk1/GAN_dataset//train/4760_0142_0231/processed_data/snapshot.h5
# Sampling Done

# %%
plotz(model, s=64, n=0, tau=1.,  c=0)
# Out:
# /home/cluster/hlasco/bulk1/GAN_dataset//train/4760_0142_0231/processed_data/snapshot.h5

# %%
s=128
N=32
lr, hr = readCube(fList_t[0], s=s)
hr = np.float32(hr + np.random.uniform(-.5/N, .5/N, hr.shape))
#lr = np.float32(lr + np.random.uniform(-.5/N, .5/N, lr.shape))
z = model.prior.sample(hr.shape).numpy()
sr = model.decode(z, y_cond=lr).numpy()
#sr = model.sample(n=1, shape=hr.shape, tau=.7, y_cond=lr )
# Out:
# /home/cluster/hlasco/bulk1/GAN_dataset//train/4760_0142_0231/processed_data/snapshot.h5

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

X = Y = Z = np.linspace(-1, 1, s)
X, Y = np.meshgrid(X, X)
levels = 100
fig = plt.figure(figsize=(24,18))
m = np.zeros(4)
M = np.zeros(4)
for cnum in range(4):
    ax = plt.subplot(1,4,cnum+1,projection='3d')
    if cnum==3:
        cmap='inferno'
        cm=plt.cm.inferno
    else:
        cmap='RdBu'
        cm=plt.cm.RdBu
    u1 = hr[0,:,:,-1,cnum]
    u2 = hr[0,:,-1,:,cnum]
    u3 = hr[0,0,:,:,cnum].T
    m[cnum] = np.min([u1, u2, u3])
    M[cnum] = np.max([u1, u2, u3])
    norm=mpl.colors.Normalize(vmin=m[cnum], vmax=M[cnum])
    ax.plot_surface(1, X, Y, facecolors=cm(norm(u2.T)),shade=False)
    ax.plot_surface(X, -1, Y, facecolors=cm(norm(u3)),rstride=1, cstride=1, shade=False)
    ax.plot_surface(X, Y, np.atleast_2d(1), facecolors=cm(norm(u1)),rstride=1, shade=False,cstride=1)
    # setting 3D-axis-limits:    
    ax.set_xlim3d(-1,1)
    ax.set_ylim3d(-1,1)
    ax.set_zlim3d(-1,1)

plt.show()
fig = plt.figure(figsize=(24,18))

for cnum in range(4):
    ax = plt.subplot(1,4,cnum+1,projection='3d')
    if cnum==3:
        cmap='inferno'
        cm=plt.cm.inferno
    else:
        cmap='RdBu'
        cm=plt.cm.RdBu
    u1 = sr[0,:,:,-1,cnum]
    u2 = sr[0,:,-1,:,cnum]
    u3 = sr[0,0,:,:,cnum].T
    
    norm=mpl.colors.Normalize(vmin=m[cnum], vmax=M[cnum])
    # this is the example that worked for you:
    ax.plot_surface(1, X, Y, facecolors=cm(norm(u2.T)), norm=norm, rstride=1, cstride=1, shade=False)
    ax.plot_surface(X, -1, Y, facecolors=cm(norm(u3)), norm=norm, rstride=1, cstride=1, shade=False)
    ax.plot_surface(X, Y, np.atleast_2d(1), facecolors=cm(norm(u1)), norm=norm, rstride=1, shade=False,cstride=1)
    ax.set_xlim3d(-1,1)
    ax.set_ylim3d(-1,1)
    ax.set_zlim3d(-1,1)
plt.show()

X = np.linspace(-1, 1, s//4)
X, Y = np.meshgrid(X, X)
fig = plt.figure(figsize=(24,18))
for cnum in range(4):
    ax = plt.subplot(1,4,cnum+1,projection='3d')
    if cnum==3:
        cmap='inferno'
        cm=plt.cm.inferno
    else:
        cmap='RdBu'
        cm=plt.cm.RdBu
    u1 = lr[0,:,:,-1,cnum]
    u2 = lr[0,:,-1,:,cnum]
    u3 = lr[0,0,:,:,cnum].T
    
    norm=mpl.colors.Normalize(vmin=m[cnum], vmax=M[cnum])
    ax.plot_surface(1, X, Y, facecolors=cm(norm(u2.T)), rstride=1, cstride=1, shade=False)
    ax.plot_surface(X, -1, Y, facecolors=cm(norm(u3)), rstride=1, cstride=1, shade=False)
    ax.plot_surface(X, Y, np.atleast_2d(1), facecolors=cm(norm(u1)), rstride=1, shade=False,cstride=1)
    # setting 3D-axis-limits:    
    ax.set_xlim3d(-1,1)
    ax.set_ylim3d(-1,1)
    ax.set_zlim3d(-1,1)
plt.show()

# %%
s=256
lr, hr = readSlice(fList_t[60],10,s=s)
hr = hr + np.random.uniform(-0.5/100,0.5/100, size=hr.shape)
lr = lr + np.random.uniform(-0.5/100,0.5/100, size=lr.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-48af00f9465d> in <module>
#       1 s=256
# ----> 2 lr, hr = readSlice(fList_t[60],10,s=s)
#       3 hr = hr + np.random.uniform(-0.5/100,0.5/100, size=hr.shape)
#       4 lr = lr + np.random.uniform(-0.5/100,0.5/100, size=lr.shape)
#
# NameError: name 'readSlice' is not defined

# %%
sr = model.sample(n=1, shape=hr.shape, tau=1.0, y_cond=lr)
print(sr.shape)
sr_det = model.sample(n=1, shape=hr.shape, tau=0.0, y_cond=lr)
# Out:
# (1, 256, 256, 4)

# %%
test = model.transform._cond_fn()(lr)
print(test.shape)
plt.imshow(test[0,:,:,-1])
plt.colorbar()
# Out:
# (1, 64, 64, 32)

# %%
vmax = np.max(abs(hr))
vmin = -vmax
plt.figure(figsize=(3*5,4))
plt.subplot(1,3,1)
plt.imshow(np.squeeze(sr_det), cmap='RdBu', vmin=vmin, vmax=vmax)
plt.colorbar()
plt.subplot(1,3,2)
plt.imshow(np.squeeze(sr), cmap='RdBu', vmin=vmin, vmax=vmax)
plt.colorbar()
plt.subplot(1,3,3)
plt.imshow(np.squeeze(sr-sr_det))
plt.colorbar()


plt.figure(figsize=(2*5,4))
plt.subplot(1,2,1)
plt.imshow(np.squeeze(hr), cmap='RdBu', vmin=vmin, vmax=vmax)
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(np.squeeze(lr), cmap='RdBu', vmin=vmin, vmax=vmax)
plt.colorbar()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
k_hr, E_hr = spectrum(np.squeeze(hr))
k_sr, E_sr = spectrum(np.squeeze(sr))
k_sr_d, E_sr_d = spectrum(np.squeeze(sr_det))

plt.loglog(k_hr, E_hr/np.sum(E_hr))
plt.loglog(k_sr, E_sr/np.sum(E_sr))
plt.loglog(k_sr_d, E_sr_d/np.sum(E_sr_d))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-1ffa0b2f73a9> in <module>
# ----> 1 k_hr, E_hr = spectrum(np.squeeze(hr))
#       2 k_sr, E_sr = spectrum(np.squeeze(sr))
#       3 k_sr_d, E_sr_d = spectrum(np.squeeze(sr_det))
#       4
#       5 plt.loglog(k_hr, E_hr/np.sum(E_hr))
#
# <ipython-input-98-cdd31adbee89> in spectrum(image)
#       1 def spectrum(image):
# ----> 2     n, _ = image.shape
#       3     fourier_image = np.fft.fftn(image) / n**2
#       4     fourier_amplitudes = np.abs(fourier_image)**2
#       5
#
# ValueError: too many values to unpack (expected 2)

# %%
z = model.encode(hr, y_cond=lr)
plt.imshow(np.squeeze(z)[:,:], vmin=-4, vmax=4)
plt.colorbar()
plt.show()
bins = np.linspace(-5,5,100)
h = plt.hist(z.numpy()[:,:,:,:].reshape(-1), bins=bins, density=True)

plt.plot(bins, prior.prob(bins), 'k')

#plt.yscale('log')
prior_log_probs = model.prior.log_prob(z)
prior_log_probs = tf.math.reduce_mean(prior_log_probs, axis=[i for i in range(1,z.shape.rank)])
print(prior_log_probs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-a0758409624c> in <module>
# ----> 1 z = model.encode(hr, y_cond=lr)
#       2 plt.imshow(np.squeeze(z)[:,:], vmin=-4, vmax=4)
#       3 plt.colorbar()
#       4 plt.show()
#       5 bins = np.linspace(-5,5,100)
#
# /net/cephfs/home/hlasco/normalizing_flows/models/flvm.py in encode(self, x, y_cond)
#     158     def encode(self, x, y_cond=None):
#     159         if y_cond is not None:
# --> 160             z, _ = self.transform.inverse(x, y_cond=y_cond)
#     161         else:
#     162             z, _ = self.transform.inverse(x)
#
# /net/cephfs/home/hlasco/normalizing_flows/flows/transform.py in inverse(self, z, *args, **kwargs)
#      70         """
#      71         assert not self.requires_init or self.input_shape is not None, 'not initialized'
# ---> 72         return self._inverse(z, *args, **kwargs)
#      73
#      74     def regularization_loss(self):
#
# /net/cephfs/home/hlasco/normalizing_flows/flows/invert.py in _inverse(self, z, *args, **kwargs)
#      19
#      20     def _inverse(self, z, *args, **kwargs):
# ---> 21         return self.transform.forward(z, *args, **kwargs)
#      22
#      23     def _forward_shape(self, shape: tf.TensorShape):
#
# /net/cephfs/home/hlasco/normalizing_flows/flows/transform.py in forward(self, z, *args, **kwargs)
#      62         """
#      63         assert not self.requires_init or self.input_shape is not None, 'not initialized'
# ---> 64         return self._forward(z, *args, **kwargs)
#      65
#      66     def inverse(self, z, *args, **kwargs):
#
# /net/cephfs/home/hlasco/normalizing_flows/flows/cglow/cglow_flow_SR.py in _forward(self, x, return_zs, **kwargs)
#     225             layer = self.layers[i]
#     226             u_reshaped = reshape_cond(u, i, self.upfactor)
# --> 227             (x_i, z_i), fldj_i = layer.forward(x_i, y_cond=u_reshaped)
#     228             fldj += fldj_i
#     229             zs.append(z_i)
#
# /net/cephfs/home/hlasco/normalizing_flows/flows/transform.py in forward(self, z, *args, **kwargs)
#      62         """
#      63         assert not self.requires_init or self.input_shape is not None, 'not initialized'
# ---> 64         return self._forward(z, *args, **kwargs)
#      65
#      66     def inverse(self, z, *args, **kwargs):
#
# /net/cephfs/home/hlasco/normalizing_flows/flows/flow.py in _forward(self, z_0, return_sequence, *params, **kwargs)
#      64             step = self.steps[i]
#      65             params_i = [params[i]] if len(params) > i else []
# ---> 66             z_i, ldj_i = step.forward(zs[-1], *params_i, **kwargs)
#      67             zs.append(z_i)
#      68             ldj += ldj_i
#
# /net/cephfs/home/hlasco/normalizing_flows/flows/transform.py in forward(self, z, *args, **kwargs)
#      62         """
#      63         assert not self.requires_init or self.input_shape is not None, 'not initialized'
# ---> 64         return self._forward(z, *args, **kwargs)
#      65
#      66     def inverse(self, z, *args, **kwargs):
#
# /net/cephfs/home/hlasco/normalizing_flows/flows/glow/act_norm.py in _forward(self, x, **kwargs)
#      59         if 'init' in kwargs and kwargs['init']:
#      60             self._init_from_data(x)
# ---> 61         return act_norm(x, var(self.log_s), var(self.b))
#      62
#      63     def _inverse(self, y, **kwargs):
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     616       # In this case we have not created variables on the first call. So we can
#     617       # run the first trace but we should fail if variables are created.
# --> 618       results = self._stateful_fn(*args, **kwds)
#     619       if self._created_variables:
#     620         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2417     """Calls a graph function specialized to the inputs."""
#    2418     with self._lock:
# -> 2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2775
#    2776       self._function_cache.missed.add(call_context_key)
# -> 2777       graph_function = self._create_graph_function(args, kwargs)
#    2778       self._function_cache.primary[cache_key] = graph_function
#    2779       return graph_function, args, kwargs
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2655     arg_names = base_arg_names + missing_arg_names
#    2656     graph_function = ConcreteFunction(
# -> 2657         func_graph_module.func_graph_from_py_func(
#    2658             self._name,
#    2659             self._python_function,
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     979         _, original_func = tf_decorator.unwrap(python_func)
#     980
# --> 981       func_outputs = python_func(*func_args, **func_kwargs)
#     982
#     983       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     439         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     440         # the function a weak reference to itself to avoid a reference cycle.
# --> 441         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     442     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     443
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     966           except Exception as e:  # pylint:disable=broad-except
#     967             if hasattr(e, "ag_error_metadata"):
# --> 968               raise e.ag_error_metadata.to_exception(e)
#     969             else:
#     970               raise
#
# TypeError: in user code:
#
#     /net/cephfs/home/hlasco/normalizing_flows/flows/glow/act_norm.py:13 act_norm  *
#         y = tf.math.exp(-log_s)*x - b
#     /home/cluster/hlasco/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py:984 binary_op_wrapper
#         return func(x, y, name=name)
#     /home/cluster/hlasco/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py:1283 _mul_dispatch
#         return gen_math_ops.mul(x, y, name=name)
#     /home/cluster/hlasco/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/ops/gen_math_ops.py:6091 mul
#         _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     /home/cluster/hlasco/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py:503 _apply_op_helper
#         raise TypeError(
#
#     TypeError: Input 'y' of 'Mul' Op has type float64 that does not match type float32 of argument 'x'.

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
from flows.invert import Invert
from flows.glow.glow_flow_SR import GlowFlowSR
from flows.glow.squeeze import Squeeze
from flows.glow.gaussianize import Gaussianize
from flows.glow.cond_affine_coupling import CondAffineCoupling, cond_coupling_nn_glow
from flows.glow.split import Split
from flows.glow.invertible_conv import InvertibleConv
from models.flvm import FlowLVM

import matplotlib.pyplot as plt
import h5py
from matplotlib.colors import LogNorm, SymLogNorm

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(3)

# %%
dset_dir = '/home/cluster/hlasco/bulk1/GAN_dataset/'
fList_t  = glob.glob(dset_dir+'/train/*/processed_data/snapshot.h5')
nFiles_t = len(fList_t)
idxList = [i for i in range(256)]
sliceList_t = [[a, b] for a in fList_t for b in idxList]
sliceList_t = np.array(sliceList_t)
np.random.shuffle(sliceList_t)

# read .h5 file
def readH5(f):
    f = f.numpy()
    file = f[0]
    idx =  int(f[1])
    with h5py.File(file, 'r') as fi:
        u_hr = np.array(fi['HR/ux'][:128,:128,idx], dtype=np.float32).reshape(128,128,1)
        u_lr = np.array(fi['LR/ux'][:32,:32,idx//4], dtype=np.float32).reshape(32,32,1)
        
        m_vel = tf.math.reduce_mean(u_hr)
        s_vel = tf.math.reduce_std(u_hr)

        u_hr = (u_hr - m_vel)/s_vel
        u_lr = (u_lr - m_vel)/s_vel
        return u_lr, u_hr


def readH5_wrapper(filename):
    # Assuming your data and labels are float32
    # Your input is parse_function, who arg is filename, and you get X and y as output
    # whose datatypes are indicated by the tuple argument
    lr, hr = tf.py_function(readH5, [filename], (tf.float32, tf.float32))
    return hr, lr

batch_size = 1
# Create dataset of filenames.
X_train_ds = tf.data.Dataset.from_tensor_slices(sliceList_t)
X_train_ds = X_train_ds.map(readH5_wrapper)
X_train_ds = X_train_ds.batch(batch_size)#.repeat()
#X_train_ds = X_train_ds.batch(1).repeat()
print(X_train_ds.cardinality())
# Out:
# tf.Tensor(21504, shape=(), dtype=int64)

# %%
coupling = cond_coupling_nn_glow(dim=2, min_filters=32, max_filters=256, num_blocks=0)
injector = injector_nn_glow(dim=2, min_filters=32, max_filters=256, num_blocks=0)
glow = CGlowFlowSR(upfactor=2,
                      num_layers=3, 
                      depth=8, 
                      cond_shape=tf.TensorShape((None,None,None,4)),
                      coupling_nn_ctor=coupling,
                      injector_nn_ctor=injector)
glow = Invert(glow)

steps_per_epoch = len(sliceList_t) // batch_size

learning_rate = 2.0e-3
model = FlowLVM(glow, input_shape=tf.TensorShape((None,None,None,4)), 
                optimizer_flow=tf.keras.optimizers.Adam(learning_rate=learning_rate))
print(model.param_count())
# Out:
# Model: "functional_207"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_107 (InputLayer)          [(None, None, None,  0
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 20736       input_107[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 64          cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# activation_690 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 1024        activation_690[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 64          cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# activation_691 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 9248        activation_691[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 64          cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# activation_692 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 9248        activation_692[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 64          cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# add_192 (Add)                   (None, None, None, 3 0           activation_691[0][0]
#                                                                  cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# activation_693 (Activation)     (None, None, None, 3 0           add_192[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 9248        activation_693[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 64          cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# activation_694 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 9248        activation_694[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 64          cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# add_193 (Add)                   (None, None, None, 3 0           activation_693[0][0]
#                                                                  cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# activation_695 (Activation)     (None, None, None, 3 0           add_193[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 9248        activation_695[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 64          cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# activation_696 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 9248        activation_696[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 64          cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# add_194 (Add)                   (None, None, None, 3 0           activation_695[0][0]
#                                                                  cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# activation_697 (Activation)     (None, None, None, 3 0           add_194[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 9248        activation_697[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 64          cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# activation_698 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 9248        activation_698[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 3 64          cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# add_195 (Add)                   (None, None, None, 3 0           activation_697[0][0]
#                                                                  cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# activation_699 (Activation)     (None, None, None, 3 0           add_195[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 8 2312        activation_699[0][0]
# __________________________________________________________________________________________________
# activation_700 (Activation)     (None, None, None, 8 0           cglow_flow_layer0_step0_cond_affi
# __________________________________________________________________________________________________
# lambda_194 (Lambda)             (None, None, None, 8 0           activation_700[0][0]
# __________________________________________________________________________________________________
# lambda_195 (Lambda)             (None, None, None, 8 0           lambda_194[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step0_cond_af (None, None, None, 8 2312        activation_699[0][0]
# ==================================================================================================
# Total params: 101,008
# Trainable params: 101,008
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "functional_211"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_109 (InputLayer)          [(None, None, None,  0
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 20736       input_109[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 64          cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# activation_704 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 1024        activation_704[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 64          cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# activation_705 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 9248        activation_705[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 64          cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# activation_706 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 9248        activation_706[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 64          cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# add_196 (Add)                   (None, None, None, 3 0           activation_705[0][0]
#                                                                  cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# activation_707 (Activation)     (None, None, None, 3 0           add_196[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 9248        activation_707[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 64          cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# activation_708 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 9248        activation_708[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 64          cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# add_197 (Add)                   (None, None, None, 3 0           activation_707[0][0]
#                                                                  cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# activation_709 (Activation)     (None, None, None, 3 0           add_197[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 9248        activation_709[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 64          cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# activation_710 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 9248        activation_710[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 64          cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# add_198 (Add)                   (None, None, None, 3 0           activation_709[0][0]
#                                                                  cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# activation_711 (Activation)     (None, None, None, 3 0           add_198[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 9248        activation_711[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 64          cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# activation_712 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 9248        activation_712[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 3 64          cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# add_199 (Add)                   (None, None, None, 3 0           activation_711[0][0]
#                                                                  cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# activation_713 (Activation)     (None, None, None, 3 0           add_199[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 8 2312        activation_713[0][0]
# __________________________________________________________________________________________________
# activation_714 (Activation)     (None, None, None, 8 0           cglow_flow_layer0_step1_cond_affi
# __________________________________________________________________________________________________
# lambda_198 (Lambda)             (None, None, None, 8 0           activation_714[0][0]
# __________________________________________________________________________________________________
# lambda_199 (Lambda)             (None, None, None, 8 0           lambda_198[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step1_cond_af (None, None, None, 8 2312        activation_713[0][0]
# ==================================================================================================
# Total params: 101,008
# Trainable params: 101,008
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "functional_215"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_111 (InputLayer)          [(None, None, None,  0
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 20736       input_111[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 64          cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# activation_718 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 1024        activation_718[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 64          cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# activation_719 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 9248        activation_719[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 64          cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# activation_720 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 9248        activation_720[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 64          cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# add_200 (Add)                   (None, None, None, 3 0           activation_719[0][0]
#                                                                  cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# activation_721 (Activation)     (None, None, None, 3 0           add_200[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 9248        activation_721[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 64          cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# activation_722 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 9248        activation_722[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 64          cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# add_201 (Add)                   (None, None, None, 3 0           activation_721[0][0]
#                                                                  cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# activation_723 (Activation)     (None, None, None, 3 0           add_201[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 9248        activation_723[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 64          cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# activation_724 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 9248        activation_724[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 64          cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# add_202 (Add)                   (None, None, None, 3 0           activation_723[0][0]
#                                                                  cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# activation_725 (Activation)     (None, None, None, 3 0           add_202[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 9248        activation_725[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 64          cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# activation_726 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 9248        activation_726[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 3 64          cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# add_203 (Add)                   (None, None, None, 3 0           activation_725[0][0]
#                                                                  cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# activation_727 (Activation)     (None, None, None, 3 0           add_203[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 8 2312        activation_727[0][0]
# __________________________________________________________________________________________________
# activation_728 (Activation)     (None, None, None, 8 0           cglow_flow_layer0_step2_cond_affi
# __________________________________________________________________________________________________
# lambda_202 (Lambda)             (None, None, None, 8 0           activation_728[0][0]
# __________________________________________________________________________________________________
# lambda_203 (Lambda)             (None, None, None, 8 0           lambda_202[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step2_cond_af (None, None, None, 8 2312        activation_727[0][0]
# ==================================================================================================
# Total params: 101,008
# Trainable params: 101,008
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "functional_219"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_113 (InputLayer)          [(None, None, None,  0
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 20736       input_113[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 64          cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# activation_732 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 1024        activation_732[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 64          cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# activation_733 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 9248        activation_733[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 64          cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# activation_734 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 9248        activation_734[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 64          cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# add_204 (Add)                   (None, None, None, 3 0           activation_733[0][0]
#                                                                  cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# activation_735 (Activation)     (None, None, None, 3 0           add_204[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 9248        activation_735[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 64          cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# activation_736 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 9248        activation_736[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 64          cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# add_205 (Add)                   (None, None, None, 3 0           activation_735[0][0]
#                                                                  cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# activation_737 (Activation)     (None, None, None, 3 0           add_205[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 9248        activation_737[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 64          cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# activation_738 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 9248        activation_738[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 64          cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# add_206 (Add)                   (None, None, None, 3 0           activation_737[0][0]
#                                                                  cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# activation_739 (Activation)     (None, None, None, 3 0           add_206[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 9248        activation_739[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 64          cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# activation_740 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 9248        activation_740[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 3 64          cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# add_207 (Add)                   (None, None, None, 3 0           activation_739[0][0]
#                                                                  cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# activation_741 (Activation)     (None, None, None, 3 0           add_207[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 8 2312        activation_741[0][0]
# __________________________________________________________________________________________________
# activation_742 (Activation)     (None, None, None, 8 0           cglow_flow_layer0_step3_cond_affi
# __________________________________________________________________________________________________
# lambda_206 (Lambda)             (None, None, None, 8 0           activation_742[0][0]
# __________________________________________________________________________________________________
# lambda_207 (Lambda)             (None, None, None, 8 0           lambda_206[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step3_cond_af (None, None, None, 8 2312        activation_741[0][0]
# ==================================================================================================
# Total params: 101,008
# Trainable params: 101,008
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "functional_223"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_115 (InputLayer)          [(None, None, None,  0
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 20736       input_115[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 64          cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# activation_746 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 1024        activation_746[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 64          cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# activation_747 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 9248        activation_747[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 64          cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# activation_748 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 9248        activation_748[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 64          cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# add_208 (Add)                   (None, None, None, 3 0           activation_747[0][0]
#                                                                  cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# activation_749 (Activation)     (None, None, None, 3 0           add_208[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 9248        activation_749[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 64          cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# activation_750 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 9248        activation_750[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 64          cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# add_209 (Add)                   (None, None, None, 3 0           activation_749[0][0]
#                                                                  cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# activation_751 (Activation)     (None, None, None, 3 0           add_209[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 9248        activation_751[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 64          cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# activation_752 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 9248        activation_752[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 64          cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# add_210 (Add)                   (None, None, None, 3 0           activation_751[0][0]
#                                                                  cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# activation_753 (Activation)     (None, None, None, 3 0           add_210[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 9248        activation_753[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 64          cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# activation_754 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 9248        activation_754[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 3 64          cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# add_211 (Add)                   (None, None, None, 3 0           activation_753[0][0]
#                                                                  cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# activation_755 (Activation)     (None, None, None, 3 0           add_211[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 8 2312        activation_755[0][0]
# __________________________________________________________________________________________________
# activation_756 (Activation)     (None, None, None, 8 0           cglow_flow_layer0_step4_cond_affi
# __________________________________________________________________________________________________
# lambda_210 (Lambda)             (None, None, None, 8 0           activation_756[0][0]
# __________________________________________________________________________________________________
# lambda_211 (Lambda)             (None, None, None, 8 0           lambda_210[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step4_cond_af (None, None, None, 8 2312        activation_755[0][0]
# ==================================================================================================
# Total params: 101,008
# Trainable params: 101,008
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "functional_227"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_117 (InputLayer)          [(None, None, None,  0
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 20736       input_117[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 64          cglow_flow_layer0_step5_cond_affi
# __________________________________________________________________________________________________
# activation_760 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step5_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 1024        activation_760[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 64          cglow_flow_layer0_step5_cond_affi
# __________________________________________________________________________________________________
# activation_761 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step5_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 9248        activation_761[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 64          cglow_flow_layer0_step5_cond_affi
# __________________________________________________________________________________________________
# activation_762 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step5_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 9248        activation_762[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 64          cglow_flow_layer0_step5_cond_affi
# __________________________________________________________________________________________________
# add_212 (Add)                   (None, None, None, 3 0           activation_761[0][0]
#                                                                  cglow_flow_layer0_step5_cond_affi
# __________________________________________________________________________________________________
# activation_763 (Activation)     (None, None, None, 3 0           add_212[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 9248        activation_763[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 64          cglow_flow_layer0_step5_cond_affi
# __________________________________________________________________________________________________
# activation_764 (Activation)     (None, None, None, 3 0           cglow_flow_layer0_step5_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer0_step5_cond_af (None, None, None, 3 9248        activation_764[0][0]
# ...
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 147584      activation_999[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 256         cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# activation_1000 (Activation)    (None, None, None, 1 0           cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 147584      activation_1000[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 256         cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# add_280 (Add)                   (None, None, None, 1 0           activation_999[0][0]
#                                                                  cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# activation_1001 (Activation)    (None, None, None, 1 0           add_280[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 147584      activation_1001[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 256         cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# activation_1002 (Activation)    (None, None, None, 1 0           cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 147584      activation_1002[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 256         cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# add_281 (Add)                   (None, None, None, 1 0           activation_1001[0][0]
#                                                                  cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# activation_1003 (Activation)    (None, None, None, 1 0           add_281[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 147584      activation_1003[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 256         cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# activation_1004 (Activation)    (None, None, None, 1 0           cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 147584      activation_1004[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 256         cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# add_282 (Add)                   (None, None, None, 1 0           activation_1003[0][0]
#                                                                  cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# activation_1005 (Activation)    (None, None, None, 1 0           add_282[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 147584      activation_1005[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 256         cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# activation_1006 (Activation)    (None, None, None, 1 0           cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 147584      activation_1006[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 1 256         cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# add_283 (Add)                   (None, None, None, 1 0           activation_1005[0][0]
#                                                                  cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# activation_1007 (Activation)    (None, None, None, 1 0           add_283[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 3 36896       activation_1007[0][0]
# __________________________________________________________________________________________________
# activation_1008 (Activation)    (None, None, None, 3 0           cglow_flow_layer2_step6_cond_affi
# __________________________________________________________________________________________________
# lambda_282 (Lambda)             (None, None, None, 3 0           activation_1008[0][0]
# __________________________________________________________________________________________________
# lambda_283 (Lambda)             (None, None, None, 3 0           lambda_282[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step6_cond_af (None, None, None, 3 36896       activation_1007[0][0]
# ==================================================================================================
# Total params: 1,384,000
# Trainable params: 1,384,000
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "functional_303"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_155 (InputLayer)          [(None, None, None,  0
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 110592      input_155[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 256         cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# activation_1012 (Activation)    (None, None, None, 1 0           cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 16384       activation_1012[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 256         cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# activation_1013 (Activation)    (None, None, None, 1 0           cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 147584      activation_1013[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 256         cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# activation_1014 (Activation)    (None, None, None, 1 0           cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 147584      activation_1014[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 256         cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# add_284 (Add)                   (None, None, None, 1 0           activation_1013[0][0]
#                                                                  cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# activation_1015 (Activation)    (None, None, None, 1 0           add_284[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 147584      activation_1015[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 256         cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# activation_1016 (Activation)    (None, None, None, 1 0           cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 147584      activation_1016[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 256         cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# add_285 (Add)                   (None, None, None, 1 0           activation_1015[0][0]
#                                                                  cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# activation_1017 (Activation)    (None, None, None, 1 0           add_285[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 147584      activation_1017[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 256         cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# activation_1018 (Activation)    (None, None, None, 1 0           cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 147584      activation_1018[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 256         cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# add_286 (Add)                   (None, None, None, 1 0           activation_1017[0][0]
#                                                                  cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# activation_1019 (Activation)    (None, None, None, 1 0           add_286[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 147584      activation_1019[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 256         cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# activation_1020 (Activation)    (None, None, None, 1 0           cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 147584      activation_1020[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 1 256         cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# add_287 (Add)                   (None, None, None, 1 0           activation_1019[0][0]
#                                                                  cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# activation_1021 (Activation)    (None, None, None, 1 0           add_287[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 3 36896       activation_1021[0][0]
# __________________________________________________________________________________________________
# activation_1022 (Activation)    (None, None, None, 3 0           cglow_flow_layer2_step7_cond_affi
# __________________________________________________________________________________________________
# lambda_286 (Lambda)             (None, None, None, 3 0           activation_1022[0][0]
# __________________________________________________________________________________________________
# lambda_287 (Lambda)             (None, None, None, 3 0           lambda_286[0][0]
# __________________________________________________________________________________________________
# cglow_flow_layer2_step7_cond_af (None, None, None, 3 36896       activation_1021[0][0]
# ==================================================================================================
# Total params: 1,384,000
# Trainable params: 1,384,000
# Non-trainable params: 0
# __________________________________________________________________________________________________
# tf.Tensor(18073520, shape=(), dtype=int32)

# %%
# Out:
# 4.0

# %%
model._init_checkpoint()
model.load(
    '/home/cluster/hlasco/scratch/srflow_2d/3_8_64_64_0/model', 
           save_num=1)

# %%
model.test(shape=[1,64,64,4], y_shape=[1,16,16,4])
# Out:
# Testing individual layers:
# Testing cglow_flow_layer0_squeeze
# 	 passed
# 	 Num params: 0
# Testing cglow_flow_layer0_trs_act_norm
# 	 passed
# 	 Num params: tf.Tensor(32, shape=(), dtype=int32)
# Testing cglow_flow_layer0_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(800, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step0_act_norm
# 	 passed
# 	 Num params: tf.Tensor(32, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step0_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(800, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step0_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(11376, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step0_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(81496, shape=(), dtype=int32)
# 	 Num params: 93704
# Testing cglow_flow_layer0_step1_act_norm
# 	 passed
# 	 Num params: tf.Tensor(32, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step1_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(800, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step1_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(11376, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step1_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(81496, shape=(), dtype=int32)
# 	 Num params: 93704
# Testing cglow_flow_layer0_step2_act_norm
# 	 passed
# 	 Num params: tf.Tensor(32, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step2_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(800, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step2_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(11376, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step2_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(81496, shape=(), dtype=int32)
# 	 Num params: 93704
# Testing cglow_flow_layer0_step3_act_norm
# 	 passed
# 	 Num params: tf.Tensor(32, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step3_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(800, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step3_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(11376, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step3_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(81496, shape=(), dtype=int32)
# 	 Num params: 93704
# Testing cglow_flow_layer0_step4_act_norm
# 	 passed
# 	 Num params: tf.Tensor(32, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step4_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(800, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step4_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(11376, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step4_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(81496, shape=(), dtype=int32)
# 	 Num params: 93704
# Testing cglow_flow_layer0_step5_act_norm
# 	 passed
# 	 Num params: tf.Tensor(32, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step5_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(800, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step5_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(11376, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step5_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(81496, shape=(), dtype=int32)
# 	 Num params: 93704
# Testing cglow_flow_layer0_step6_act_norm
# 	 passed
# 	 Num params: tf.Tensor(32, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step6_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(800, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step6_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(11376, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step6_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(81496, shape=(), dtype=int32)
# 	 Num params: 93704
# Testing cglow_flow_layer0_step7_act_norm
# 	 passed
# 	 Num params: tf.Tensor(32, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step7_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(800, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step7_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(11376, shape=(), dtype=int32)
# Testing cglow_flow_layer0_step7_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(81496, shape=(), dtype=int32)
# 	 Num params: 93704
# Testing cglow_flow_layer0_split
# 	 passed
# 	 Num params: 101648
# Testing cglow_flow_layer1_squeeze
# 	 passed
# 	 Num params: 0
# Testing cglow_flow_layer1_trs_act_norm
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer1_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step0_act_norm
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step0_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step0_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(41184, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step0_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(320176, shape=(), dtype=int32)
# 	 Num params: 364560
# Testing cglow_flow_layer1_step1_act_norm
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step1_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step1_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(41184, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step1_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(320176, shape=(), dtype=int32)
# 	 Num params: 364560
# Testing cglow_flow_layer1_step2_act_norm
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step2_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step2_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(41184, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step2_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(320176, shape=(), dtype=int32)
# 	 Num params: 364560
# Testing cglow_flow_layer1_step3_act_norm
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step3_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step3_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(41184, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step3_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(320176, shape=(), dtype=int32)
# 	 Num params: 364560
# Testing cglow_flow_layer1_step4_act_norm
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step4_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step4_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(41184, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step4_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(320176, shape=(), dtype=int32)
# 	 Num params: 364560
# Testing cglow_flow_layer1_step5_act_norm
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step5_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step5_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(41184, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step5_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(320176, shape=(), dtype=int32)
# 	 Num params: 364560
# Testing cglow_flow_layer1_step6_act_norm
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step6_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step6_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(41184, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step6_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(320176, shape=(), dtype=int32)
# 	 Num params: 364560
# Testing cglow_flow_layer1_step7_act_norm
# 	 passed
# 	 Num params: tf.Tensor(64, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step7_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(3136, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step7_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(41184, shape=(), dtype=int32)
# Testing cglow_flow_layer1_step7_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(320176, shape=(), dtype=int32)
# 	 Num params: 364560
# Testing cglow_flow_layer1_split
# 	 passed
# 	 Num params: 129312
# Testing cglow_flow_layer2_squeeze
# 	 passed
# 	 Num params: 0
# Testing cglow_flow_layer2_trs_act_norm
# 	 passed
# 	 Num params: tf.Tensor(128, shape=(), dtype=int32)
# Testing cglow_flow_layer2_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(12416, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step0_act_norm
# 	 passed
# 	 Num params: tf.Tensor(128, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step0_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(12416, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step0_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(156096, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step0_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(1269088, shape=(), dtype=int32)
# 	 Num params: 1437728
# Testing cglow_flow_layer2_step1_act_norm
# 	 passed
# 	 Num params: tf.Tensor(128, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step1_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(12416, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step1_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(156096, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step1_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(1269088, shape=(), dtype=int32)
# 	 Num params: 1437728
# Testing cglow_flow_layer2_step2_act_norm
# 	 passed
# 	 Num params: tf.Tensor(128, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step2_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(12416, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step2_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(156096, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step2_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(1269088, shape=(), dtype=int32)
# 	 Num params: 1437728
# Testing cglow_flow_layer2_step3_act_norm
# 	 passed
# 	 Num params: tf.Tensor(128, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step3_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(12416, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step3_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(156096, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step3_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(1269088, shape=(), dtype=int32)
# 	 Num params: 1437728
# Testing cglow_flow_layer2_step4_act_norm
# 	 passed
# 	 Num params: tf.Tensor(128, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step4_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(12416, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step4_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(156096, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step4_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(1269088, shape=(), dtype=int32)
# 	 Num params: 1437728
# Testing cglow_flow_layer2_step5_act_norm
# 	 passed
# 	 Num params: tf.Tensor(128, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step5_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(12416, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step5_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(156096, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step5_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(1269088, shape=(), dtype=int32)
# 	 Num params: 1437728
# Testing cglow_flow_layer2_step6_act_norm
# 	 passed
# 	 Num params: tf.Tensor(128, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step6_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(12416, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step6_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(156096, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step6_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(1269088, shape=(), dtype=int32)
# 	 Num params: 1437728
# Testing cglow_flow_layer2_step7_act_norm
# 	 passed
# 	 Num params: tf.Tensor(128, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step7_inv_conv
# 	 passed
# 	 Num params: tf.Tensor(12416, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step7_affine_injector
# 	 passed
# 	 Num params: tf.Tensor(156096, shape=(), dtype=int32)
# Testing cglow_flow_layer2_step7_cond_affine_coupling
# 	 passed
# 	 Num params: tf.Tensor(1269088, shape=(), dtype=int32)
# 	 Num params: 1437728
# Testing gaussianize
# 	 passed
# Testing full model:
# 	 passed

# %%
#model.train(X_train_ds, steps_per_epoch//10, num_epochs=1, conditional=True)

# %%
def readSlice(f, idx, s=64):
    with h5py.File(f, 'r') as fi:
        u_hr = np.array(fi['HR/uz'][:s,:s,idx], dtype=np.float32).reshape(1,s,s,1)
        u_lr = np.array(fi['LR/uz'][:s//4,:s//4,idx//4], dtype=np.float32).reshape(1,s//4,s//4,1)
        
        #u_hr = np.log10(u_hr)
        #u_lr = np.log10(u_lr)
        
        m_vel = tf.math.reduce_mean(u_hr)
        s_vel = tf.math.reduce_std(u_hr)

        u_hr = (u_hr - m_vel)/s_vel
        u_lr = (u_lr - m_vel)/s_vel
        return u_lr, u_hr

# %%
lr, hr = readSlice(fList_t[0],10,s=128)

print(np.mean(lr))
# Out:
# 0.019619826

# %%
sr = model.sample(n=1, shape=hr.shape, 
                  tau=1.0, y_cond=lr)
print(sr.shape)
sr_det = model.sample(n=1, shape=hr.shape, 
                      tau=0.0, y_cond=lr)
# Out:
# (1, 128, 128, 1)

# %%
vmin = np.min(hr)
vmax = np.max(hr)
plt.figure(figsize=(4*5,4))
plt.subplot(1,4,1)
plt.imshow(np.squeeze(sr_det), cmap='RdBu', vmin=vmin, vmax=vmax)
plt.colorbar()
plt.subplot(1,4,2)
plt.imshow(np.squeeze(sr), cmap='RdBu', vmin=vmin, vmax=vmax)
plt.colorbar()
plt.subplot(1,4,3)
plt.imshow(np.fabs(np.squeeze(sr_det-sr))/np.std(sr_det),vmin=0, vmax=2)
plt.colorbar()
plt.subplot(1,4,4)
plt.imshow(np.fabs(np.squeeze(sr_det-hr))/np.std(sr_det), vmin=0, vmax=2)
plt.colorbar()

plt.figure(figsize=(2*5,4))
plt.subplot(1,2,1)
plt.imshow(np.squeeze(hr), cmap='RdBu', vmin=vmin, vmax=vmax)
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(np.squeeze(lr), cmap='RdBu', vmin=vmin, vmax=vmax)
plt.colorbar()

# %%
k_hr, E_hr = spectrum(np.squeeze(hr))
k_sr, E_sr = spectrum(np.squeeze(sr))
k_sr_d, E_sr_d = spectrum(
    np.squeeze(sr_det))

plt.loglog(k_hr, E_hr)
plt.loglog(k_sr, E_sr)
plt.loglog(k_sr_d, E_sr_d)

# %%
test = model.transform._cond_fn()(lr)
print(test.shape)
plt.imshow(test[0,:,:,0])
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-121-170c089a9510> in <module>
# ----> 1 test = model.transform._cond_fn()(lr)
#       2 print(test.shape)
#       3 plt.imshow(test[0,:,:,0])
#       4 plt.colorbar()
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in call(self, inputs, training, mask)
#     383         a list of tensors if there are more than one outputs.
#     384     """
# --> 385     return self._run_internal_graph(
#     386         inputs, training=training, mask=mask)
#     387
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     506
#     507         args, kwargs = node.map_arguments(tensor_dict)
# --> 508         outputs = node.layer(*args, **kwargs)
#     509
#     510         # Update tensor_dict.
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/keras/layers/convolutional.py in call(self, inputs)
#     245       inputs = array_ops.pad(inputs, self._compute_causal_padding(inputs))
#     246
# --> 247     outputs = self._convolution_op(inputs, self.kernel)
#     248
#     249     if self.use_bias:
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1009     dilations=None,
#    1010     name=None):
# -> 1011   return convolution_internal(
#    1012       input,  # pylint: disable=redefined-builtin
#    1013       filters,
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1139         op = conv1d
#    1140
# -> 1141       return op(
#    1142           input,
#    1143           filters,
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2583     # We avoid calling squeeze_batch_dims to reduce extra python function
#    2584     # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2585     return gen_nn_ops.conv2d(
#    2586         input,
#    2587         filter=filters,
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     936       return _result
#     937     except _core._NotOkStatusException as e:
# --> 938       _ops.raise_from_not_ok_status(e, name)
#     939     except _core._FallbackException:
#     940       pass
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# ~/bulk1/miniconda3/envs/pyenv/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: input depth must be evenly divisible by filter depth: 1 vs 4 [Op:Conv2D]

# %%
z = model.encode(hr, y_cond=lr)

plt.imshow(np.squeeze(z), vmin=-5, vmax=5)
plt.colorbar()
plt.show()
bins = np.linspace(-4,4,100)
h = plt.hist(z.numpy().flat, bins=bins, density=True)

prior = tfp.distributions.Normal(loc=0, scale=1.0)
plt.plot(bins, prior.prob(bins), 'k')
#plt.yscale('log')
prior_log_probs = prior.log_prob(z)
prior_log_probs = tf.math.reduce_mean(prior_log_probs, axis=[i for i in range(1,z.shape.rank)])
print(prior_log_probs)
# Out:
# tf.Tensor([-1.4747056], shape=(1,), dtype=float32)

# %%
z1=z.numpy()*0
#z1[:,:128,:256,:]=prior.sample((1,128,256,1))
#z1[:,128:192,:,:]=prior.sample((1,64,256,1))
z1[:,112:128,:,:]=prior.sample((1,16,128,1))
#z1[:,224:,:,:]=prior.sample((1,32,128,1))
plt.imshow(np.squeeze(z1))
plt.colorbar()
plt.show()

im=model.decode(z1, y_cond=lr)
plt.imshow(np.squeeze(im), cmap='RdBu')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-7a94a2b946b7> in <module>
#       2 #z1[:,:128,:256,:]=prior.sample((1,128,256,1))
#       3 #z1[:,128:192,:,:]=prior.sample((1,64,256,1))
# ----> 4 z1[:,112:128,:,:]=prior.sample((1,16,128,1))
#       5 #z1[:,224:,:,:]=prior.sample((1,32,128,1))
#       6 plt.imshow(np.squeeze(z1))
#
# ValueError: could not broadcast input array from shape (1,16,128,1) into shape (1,16,256,1)

# %%
shape = np.array([64,64,64,4])
n = np.prod(shape)
n1 = 0
print(n)
for i in range(5):
    new_shape = shape
    new_shape[:3] = shape[:3]//2
    new_shape[-1] = shape[-1]*2**2
    n1 += np.prod(new_shape)
    print(new_shape, np.prod(new_shape))
    if i==4:
        n1 += np.prod(new_shape)
print(n1)
# Out:
# 1048576
# [32 32 32 16] 524288
# [16 16 16 64] 262144
# [  8   8   8 256] 131072
# [   4    4    4 1024] 65536
# [   2    2    2 4096] 32768
# 1048576

# %%
x = np.zeros((1,2,2,2,4))
x[0,0,0,0,1] = 1
x[0,0,0,1,1] = 2
x[0,0,1,0,1] = 3
x[0,0,1,1,1] = 4
x[0,1,0,0,1] = 5
x[0,1,0,1,1] = 6
x[0,1,1,0,1] = 7
x[0,1,1,1,1] = 8

# %%
shape = x.shape
factor = 2
h, w, d, c = shape[1:]
# pad to divisor
# reshape to intermediate tensor
s1, s2, s3 = h//factor, w//factor, d//factor
x_ = tf.reshape(x, (-1, s1, factor, s2, factor, s3, factor, c))
# transpose factored out dimensions to channel axis
x_ = tf.transpose(x_, [0, 1, 3, 5, 7, 2, 4, 6])
# reshape to final output shape
y = tf.reshape(x_, (-1, s1, s2, s3, c*factor**3))

# %%
y = tf.roll(x, shift=5, axis=-1)
x_ = tf.roll(y, shift=-5, axis=-1)
